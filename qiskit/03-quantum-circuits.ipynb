# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.primitives import Sampler
from qiskit.visualization import plot_histogram

# %%
X = QuantumRegister(1, "X")
circuit = QuantumCircuit(X)

circuit.h(0)
circuit.s(0)
circuit.h(0)
circuit.t(0)

display(circuit.draw("latex"))
# Out:
# <PIL.Image.Image image mode=RGB size=272x28>

# %%
X = QuantumRegister(1, "X")
Y = QuantumRegister(1, "Y")
A = ClassicalRegister(1, "A")
B = ClassicalRegister(1, "B")
qc = QuantumCircuit(Y, X, B, A)
qc.h(Y)
qc.cx(Y, X)
qc.measure(Y, B)
qc.measure(X, A)
display(qc.draw("latex"))
# Out:
# <PIL.Image.Image image mode=RGB size=285x132>

# %%
results = Sampler().run(qc).result()
stats = results.quasi_dists[0].binary_probabilities()
display(plot_histogram(stats))
